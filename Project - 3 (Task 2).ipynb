# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# Import the data with the help of pandas function read_csv()

df = pd.read_csv("movies.csv")

# %%
# With the help of head() function lets check the first four rows of data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Finding in the data is there is any missing value or not, if yes how much percentage of missing value is in per column


for col in df.columns:
   pct_missing = np.mean(df[col].isnull())
   print('{}--{}%'.format(col, pct_missing))

    
# As we can see that the percentage of the missing value in the data is negligible so we can ingore them.
# Out:
# name--0.0%
# rating--0.010041731872717789%
# genre--0.0%
# year--0.0%
# released--0.0002608242044861763%
# score--0.0003912363067292645%
# votes--0.0003912363067292645%
# director--0.0%
# writer--0.0003912363067292645%
# star--0.00013041210224308815%
# country--0.0003912363067292645%
# budget--0.2831246739697444%
# gross--0.02464788732394366%
# company--0.002217005738132499%
# runtime--0.0005216484089723526%

# %%
# As we can see the percentage of the missing value is negligible so we are fikling it with the 0 values

df = df.fillna(value = 0)

# %%
# Let's see if the data type of all the column is correct or not

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing the types of the nessery column
df['budget'] = df['budget'].astype(int)
df['gross'] = df['gross'].astype(int)

# %%
# Agsin checking the data type of data

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int32
# gross         int32
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el          0     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
# scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs gross earning')

plt.xlabel('goss earning')

plt.ylabel('Budget for flim')

plt.ylim(0)

plt.show()

# %%
# Ploting scatter plot of budget vs gross

sns.regplot(x='budget', y='gross', data=df, scatter_kws = {'color' : 'black'}, line_kws = {'color': 'red'})

plt.ylim(0)
# Out:
# (0.0, 2280371967.4)

# %%
# let's check the correlation between the budget and gross 

df['budget'].corr(df['gross'])

# As there is strong correlation between budget and gross
# Out:
# 0.6871244280309573

# %%
# Scatter plot of votes vs gross

plt.scatter(x=df['votes'], y=df['gross'])

plt.title('votes vs gross')

plt.xlabel('gross earning')

plt.ylabel('votes')

plt.ylim(0)

plt.show()

# %%
# Ploting scatter plot of budget vs gross

sns.regplot(x='votes', y= 'gross', data = df, scatter_kws = {'color' : 'black'}, line_kws = {'color': 'red'})

plt.ylim(0)
# Out:
# (0.0, 2280371967.4)

# %%
# Let's check the correlation betwween the votes and goss

df['votes'].corr(df['gross'])

# As we can see in the result there is moderate correlation between votes and goss
# Out:
# 0.5739299923357983

# %%
# scatter plot of runtime vs budget

plt.scatter(x=df['runtime'], y=df['budget'])

plt.title('runtime vs Budget')

plt.xlabel('Budget of the movie')

plt.ylabel('runtime of the movie')

plt.show()

# %%
# ploting the scatter plot of runtime vs the budget

sns.regplot(x = 'runtime', y = 'budget', data = df, scatter_kws = {'color' : 'black'}, line_kws = {'color': 'red'})

plt.ylim(0)
# Out:
# (0.0, 375870052.6957792)

# %%
# Let's check the correlation betwween the runtime and budget

df['runtime'].corr(df['budget'])

# As we can see there is week correlation between the runtime and the budget
# Out:
# 0.2683717711408565

# %%
# finding and visualzing the correlation between alll the numeric columns in the data frame

selected_columns = ['year', 'score', 'votes', 'budget', 'gross', 'runtime']

subset_df = df[selected_columns]

correlation_matrix = subset_df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Now we sre going to find the correlation of columns which are not numeric also, to do that first we have to chnage the data 
# type from object to category and then assing a random variable to each data vaue.

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3      286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000.0      1054     522
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18.0      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36.0       774    2615
# 7665  4717       0      6  2020       194    5.7       29.0      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0.0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...

# %%
# finding the correlation between alll the columns in the data frame

df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross     0.013895 -0.095355 -0.229534  0.256331  0.014154  0.169154
# ...

# %%
# visualzing the correlation between alll the columns in the data frame

correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year        0.011453
#          released   -0.011311
#                        ...
# runtime  country    -0.073319
#          budget      0.268372
#          gross       0.203616
#          company     0.037537
#          runtime     1.000000
# Length: 225, dtype: float64
